# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0       waitangi -43.9535 -176.5597     48.81        86          92
# 1        1        wodonga -36.1167  146.8833     48.11       100           0
# 2        2  malinao ilaya  14.0000  121.8333     82.51        81          99
# 3        3       qaqortoq  60.7167  -46.0333     44.01        84          95
# 4        4   pyin oo lwin  22.0333   96.4667     68.68        91          74
#
#    Wind Speed Country  Date
# 0        4.00      NZ   200
# 1        3.83      AU   200
# 2        8.61      PH   200
# 3        3.76      GL   200
# 4        1.34      MM   200

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display
map1 = city_data_df.hvplot.points("Lng", "Lat", geo=True, color="City", 
                               size="Humidity", frame_height=500, 
                               frame_width=700, tiles="OSM", scale=1, hover_cols=["Lng", "Lat"])
map1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
condition_1 = (city_data_df["Max Temp"] >= 65)
condition_2 = (city_data_df["Max Temp"] <= 80)
condition_3 = (city_data_df["Humidity"] <= 50)
ideal_df = city_data_df.loc[condition_1 & condition_2 & condition_3]

# Drop any rows with null values
ideal_df = ideal_df.dropna()

# Display sample data
ideal_df
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 26       riachao das neves -11.7461  -44.9100     71.64        37          17
# 37         cabeza del buey  38.7223   -5.2195     74.89        30           0
# 46             yellowknife  62.4560 -114.3525     77.52        31          75
# 73              whitehorse  60.7161 -135.0538     76.01        49          75
# 98                   barra -11.0894  -43.1417     74.01        50          29
# 126                   kone -21.0595  164.8658     73.81        40           2
# 153       pontes e lacerda -15.2261  -59.3353     77.20        41          12
# 154                dubovka  49.0583   44.8290     72.55        46           2
# 166               smithers  54.7804 -127.1743     66.52        48          75
# 190                klyuchi  52.2667   79.1667     70.75        41          99
# 205                ilovlya  49.3033   43.9796     74.03        43           2
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_df.loc[:, ["City", "Country", "Lat", "Lng", "Humidity"]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                       City Country      Lat       Lng  Humidity Hotel Name
# 26       riachao das neves      BR -11.7461  -44.9100        37
# 37         cabeza del buey      ES  38.7223   -5.2195        30
# 46             yellowknife      CA  62.4560 -114.3525        31
# 73              whitehorse      CA  60.7161 -135.0538        49
# 98                   barra      BR -11.0894  -43.1417        50
# 126                   kone      NC -21.0595  164.8658        40
# 153       pontes e lacerda      BR -15.2261  -59.3353        41
# 154                dubovka      RU  49.0583   44.8290        46
# 166               smithers      CA  54.7804 -127.1743        48
# 190                klyuchi      RU  52.2667   79.1667        41
# 205                ilovlya      RU  49.3033   43.9796        43
# 240                borujen      IR  31.9652   51.2873        22
# 244                 miyaly      KZ  48.8844   53.7836        45
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories":"accommodation.hotel",
    "limit":20,
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat= row["Lat"]
    lon = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# riachao das neves - nearest hotel: No hotel found
# cabeza del buey - nearest hotel: No hotel found
# yellowknife - nearest hotel: No hotel found
# whitehorse - nearest hotel: Town & Mountain Hotel
# barra - nearest hotel: No hotel found
# kone - nearest hotel: Pacifik Appartels
# pontes e lacerda - nearest hotel: Hotel Avenida
# dubovka - nearest hotel: Алиса
# smithers - nearest hotel: Sunshine Inn Hotel
# klyuchi - nearest hotel: No hotel found
# ilovlya - nearest hotel: No hotel found
# borujen - nearest hotel: هتل فجر
# miyaly - nearest hotel: Ахан
# khandyga - nearest hotel: Апельсин
# namtsy - nearest hotel: No hotel found
# banff - nearest hotel: Mount Royal Hotel
# miracema do tocantins - nearest hotel: No hotel found
# vilyuysk - nearest hotel: Мария
# zeya - nearest hotel: Серебряный створ
# lavras - nearest hotel: Pousada dos Viajantes
# beyneu - nearest hotel: Johan yu
# altai - nearest hotel: Altai hotel 40000-100000T
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map2 = hotel_df.hvplot.points("Lng", "Lat", geo=True, color="City", 
                               size="Humidity", frame_height=500, 
                               frame_width=700, tiles="OSM", scale=1, hover_cols=["Hotel Name", "Country"])

# Display the map
map2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
